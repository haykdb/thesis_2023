# %%
import tensorflow as tf
import glob
import pathlib
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt

# %%
dataset_url = r"C:\Users\hayk.darbinyan\codes\my_Venvs\_venv-310-jupyter\Thesis\Dataset\Pics_20_5\Train"
data_dir = pathlib.Path(dataset_url)

# %%
batch_size = 128
img_height = 64
img_width = 60

# %%
image_count = len(list(data_dir.glob('*/*.jpeg')))
list_ds = tf.data.Dataset.list_files(str(data_dir/'*/*'), shuffle=False)
list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=False)

# %%
for f in list_ds.take(5):
    print(f.numpy())
# Out:
# b'C:\\Users\\hayk.darbinyan\\codes\\my_Venvs\\_venv-310-jupyter\\Thesis\\Dataset\\Pics_20_5\\Train\\class_a\\a_image_4230.jpeg'
# b'C:\\Users\\hayk.darbinyan\\codes\\my_Venvs\\_venv-310-jupyter\\Thesis\\Dataset\\Pics_20_5\\Train\\class_b\\b_image_1578.jpeg'
# b'C:\\Users\\hayk.darbinyan\\codes\\my_Venvs\\_venv-310-jupyter\\Thesis\\Dataset\\Pics_20_5\\Train\\class_b\\b_image_76.jpeg'
# b'C:\\Users\\hayk.darbinyan\\codes\\my_Venvs\\_venv-310-jupyter\\Thesis\\Dataset\\Pics_20_5\\Train\\class_b\\b_image_2934.jpeg'
# b'C:\\Users\\hayk.darbinyan\\codes\\my_Venvs\\_venv-310-jupyter\\Thesis\\Dataset\\Pics_20_5\\Train\\class_b\\b_image_3017.jpeg'

# %%
class_names = np.array(sorted([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"]))
print(class_names)
# Out:
# ['class_a' 'class_b']

# %%
split_ratio = 0.5
val_size = int(image_count * split_ratio)
train_ds = list_ds.skip(val_size)
val_ds = list_ds.take(val_size)

# %%
print(tf.data.experimental.cardinality(train_ds).numpy())
print(tf.data.experimental.cardinality(val_ds).numpy())
# Out:
# 7285
# 7285

# %%
def get_label(file_path):
    # Convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    one_hot = parts[-2] == class_names
    # Integer encode the label
    return(tf.argmax(one_hot))

def decode_img(img):
    # Convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_jpeg(img)
#     print(img)
#     img = np.array(img)
#     img[img != 0] = 255
#     img = tf.convert_to_tensor(img)
    # Resize the image to the desired size
    return(tf.image.resize(img, [img_height, img_width]))

def process_path(file_path):
    label = get_label(file_path)
    # Load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return(img, label)

# %%
AUTOTUNE = tf.data.AUTOTUNE
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
train_ds = train_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=AUTOTUNE)
# Out:
# Tensor("DecodeJpeg:0", shape=(None, None, None), dtype=uint8)
# Tensor("DecodeJpeg:0", shape=(None, None, None), dtype=uint8)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (64, 60, 1)
# Label:  1

# %%
def configure_for_performance(ds):
    ds = ds.cache()
    ds = ds.shuffle(buffer_size=1000)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = configure_for_performance(train_ds)
val_ds = configure_for_performance(val_ds)

# %%
image_batch, label_batch = next(iter(train_ds))

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(image_batch[i].numpy().astype("uint8"))
  label = label_batch[i]
  plt.title(class_names[label])
  plt.axis("off")

# %%
num_classes = 2

model = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
  tf.keras.layers.Conv2D(1, (5,3), padding = 'same', strides = (2,1), activation='relu'),
#   tf.keras.layers.Conv2D(64, (5,3), padding = 'same', strides = (2,1), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, (5,3), padding = 'same', strides = (2,1), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(48, activation='relu'),
  tf.keras.layers.Dense(1, activation = 'sigmoid')
])

# %%
model.compile(
  optimizer='RMSprop',
  loss=tf.keras.losses.BinaryCrossentropy(),
  metrics=['accuracy'])

model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=100
)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [135], in <cell line: 6>()
#       1 model.compile(
#       2   optimizer='RMSprop',
#       3   loss=tf.keras.losses.BinaryCrossentropy(),
#       4   metrics=['accuracy'])
# ----> 6 model.fit(
#       7   train_ds,
#       8   validation_data=val_ds,
#       9   epochs=100
#      10 )
#
# File ~\codes\my_Venvs\_venv-310-jupyter\lib\site-packages\tensorflow\python\keras\engine\training.py:1100, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1093 with trace.Trace(
#    1094     'train',
#    1095     epoch_num=epoch,
#    1096     step_num=step,
# ...

# %%
img1 = tf.io.read_file(r"C:\Users\hayk.darbinyan\codes\my_Venvs\_venv-310-jupyter\Thesis\Dataset\Pics_20_5\Train\class_a\a_image_0.jpeg")
img6 = np.array(tf.io.decode_jpeg(img1))
img6[img6 != 0] = 255
tf.convert_to_tensor(img6)
# Out:
# <tf.Tensor: shape=(64, 60, 1), dtype=uint8, numpy=
# array([[[  0],
#         [  0],
#         [  0],
#         ...,
#         [  0],
#         [255],
#         [  0]],
#
#        [[  0],
#         [  0],
#         [  0],
#         ...,
#         [255],
#         [  0],
#         [255]],
#
#        [[  0],
#         [  0],
#         [  0],
#         ...,
#         [  0],
#         [255],
#         [  0]],
#
#        ...,
#
#        [[255],
#         [255],
#         [255],
#         ...,
#         [  0],
#         [255],
#         [  0]],
#
#        [[  0],
#         [255],
#         [  0],
#         ...,
#         [  0],
#         [255],
#         [  0]],
#
#        [[255],
#         [255],
#         [  0],
#         ...,
#         [255],
#         [255],
#         [255]]], dtype=uint8)>

# %%
img2 = tf.keras.preprocessing.image.load_img(r"C:\Users\hayk.darbinyan\codes\my_Venvs\_venv-310-jupyter\Thesis\Dataset\Pics_20_5\Train\class_a\a_image_0.jpeg", color_mode = 'grayscale')
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=60x64>

# %%
img3 = Image.open(r"C:\Users\hayk.darbinyan\codes\my_Venvs\_venv-310-jupyter\Thesis\Dataset\Pics_20_5\Train\class_a\a_image_0.jpeg")
img3 = np.array(img3)

# %%
img4[img4 != 0] = 255
img4
# Out:
# array([[  0,   0,   0, ...,   0, 255,   0],
#        [  0,   0,   0, ..., 255,   0, 255],
#        [  0,   0,   0, ...,   0, 255,   0],
#        ...,
#        [255, 255, 255, ...,   0, 255,   0],
#        [  0, 255,   0, ...,   0, 255,   0],
#        [255, 255,   0, ..., 255, 255, 255]], dtype=uint8)

# %%
img5 = Image.fromarray(img3)
img5.show()
